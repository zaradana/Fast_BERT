# %%
import sys, os
import mlflow
import mlflow.azureml

import azureml.core
from azureml.core import Workspace

ws = Workspace.from_config()

print("SDK version:", azureml.core.VERSION)
print("MLflow version:", mlflow.version.VERSION)
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# /home/zara/.local/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# SDK version: 1.18.0
# MLflow version: 1.12.1
# zd-ner
# scan-datasources-rg
# southcentralus
# d35ad7f3-a6be-400c-b1db-8b70322a01a0

# %%
mlflow.set_tracking_uri(ws.get_mlflow_tracking_uri())

experiment_name = "fast-bert-ner"
mlflow.set_experiment(experiment_name)

backend_config = {"COMPUTE": "zd", "USE_CONDA": False}

# %%
remote_mlflow_run = mlflow.projects.run(uri=".", 
                                    parameters={"json_config": "training_config.json"},
                                    backend="azureml",
                                    backend_config=backend_config, 
                                    synchronous=True)
# Out:
# ogue<1.1.0,>=0.0.7
#   Downloading catalogue-1.0.0-py2.py3-none-any.whl (7.7 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.4-cp37-cp37m-manylinux2014_x86_64.whl (35 kB)
# Collecting cycler>=0.10
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting pillow>=6.2.0
#   Downloading Pillow-8.0.1-cp37-cp37m-manylinux1_x86_64.whl (2.2 MB)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.1-cp37-cp37m-manylinux1_x86_64.whl (1.1 MB)
# Requirement already satisfied, skipping upgrade: wheel>=0.26; python_version >= "3" in /azureml-envs/azureml_37005b8e9f6980b2f008f81139d8598f/lib/python3.7/site-packages (from tensorboard>=1.14->pytorch-lightning==0.8.1->-r /azureml-environment-setup/condaenv.1vluijyv.requirements.txt (line 6)) (0.35.1)
# Collecting google-auth<2,>=1.6.3
#   Downloading google_auth-1.23.0-py2.py3-none-any.whl (114 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.7.0-py3-none-any.whl (779 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.2-py2.py3-none-any.whl (18 kB)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.3-py3-none-any.whl (96 kB)
# Collecting absl-py>=0.4
#   Downloading absl_py-0.11.0-py3-none-any.whl (127 kB)
# Collecting grpcio>=1.24.3
#   Downloading grpcio-1.33.2-cp37-cp37m-manylinux2014_x86_64.whl (3.8 MB)
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp37-cp37m-manylinux1_x86_64.whl (27 kB)
# Collecting smmap<4,>=3.0.1
#   Downloading smmap-3.0.4-py2.py3-none-any.whl (25 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting cffi!=1.11.3,>=1.8
#   Downloading cffi-1.14.4-cp37-cp37m-manylinux1_x86_64.whl (402 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9"
#   Downloading ruamel.yaml.clib-0.2.2-cp37-cp37m-manylinux1_x86_64.whl (547 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.6.0-py3-none-any.whl (45 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.4.0-py3-none-any.whl (5.2 kB)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.1 in /azureml-envs/azureml_37005b8e9f6980b2f008f81139d8598f/lib/python3.7/site-packages (from scikit-learn>=0.21.3->seqeval->fast-bert->-r /azureml-environment-setup/condaenv.1vluijyv.requirements.txt (line 5)) (1.5.3)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-2.1.0-py3-none-any.whl (12 kB)
# Collecting rsa<5,>=3.1.4; python_version >= "3.5"
#   Downloading rsa-4.6-py3-none-any.whl (47 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.1.1-py3-none-any.whl (10 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Building wheels for collected packages: prometheus-flask-exporter, pyyaml, databricks-cli, alembic, sacremoses, future, seqeval, sklearn
#   Building wheel for prometheus-flask-exporter (setup.py): started
#   Building wheel for prometheus-flask-exporter (setup.py): finished with status 'done'
#   Created wheel for prometheus-flask-exporter: filename=prometheus_flask_exporter-0.18.1-py3-none-any.whl size=17157 sha256=a728d83a03828e602bf6be5ee330e7933941d72a94501e23352bc39aaa58d561
#   Stored in directory: /root/.cache/pip/wheels/c4/b6/b5/e76659f3b2a3a226565e27f0a7eb7a3ac93c3f4d68acfbe617
#   Building wheel for pyyaml (setup.py): started
#   Building wheel for pyyaml (setup.py): finished with status 'done'
#   Created wheel for pyyaml: filename=PyYAML-5.3.1-cp37-cp37m-linux_x86_64.whl size=44619 sha256=17b2388358ed5f816a3eac6b170a5e82161782c7891c5a48a6f297a1ded98469
#   Stored in directory: /root/.cache/pip/wheels/5e/03/1e/e1e954795d6f35dfc7b637fe2277bff021303bd9570ecea653
#   Building wheel for databricks-cli (setup.py): started
#   Building wheel for databricks-cli (setup.py): finished with status 'done'
#   Created wheel for databricks-cli: filename=databricks_cli-0.14.1-py3-none-any.whl size=100577 sha256=a6c946380c34249df4adc147430e6fc11dd8d4989e5beda2bd55ab791780bd3c
#   Stored in directory: /root/.cache/pip/wheels/7f/d9/25/baefac3eda0e7dbf143008d2b9865e0d923d4b7306136244fe
#   Building wheel for alembic (setup.py): started
#   Building wheel for alembic (setup.py): finished with status 'done'
#   Created wheel for alembic: filename=alembic-1.4.1-py2.py3-none-any.whl size=158155 sha256=68ab528f59a1b9c22d0b051e3e702704ce01ed4878779e40134f26987b829a35
#   Stored in directory: /root/.cache/pip/wheels/be/5d/0a/9e13f53f4f5dfb67cd8d245bb7cdffe12f135846f491a283e3
#   Building wheel for sacremoses (setup.py): started
#   Building wheel for sacremoses (setup.py): finished with status 'done'
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-py3-none-any.whl size=893259 sha256=0d1d1cf5d81338c4aee44bac2a95db197f3a4a35bed12c22eea57351209f3f3c
#   Stored in directory: /root/.cache/pip/wheels/69/09/d1/bf058f7d6fa0ecba2ce7c66be3b8d012beb4bf61a6e0c101c0
#   Building wheel for future (setup.py): started
#   Building wheel for future (setup.py): finished with status 'done'
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491059 sha256=dce5963f450deaff012846a3216b19c8212bb2f8d53ff63530971373eb0f207b
#   Stored in directory: /root/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
#   Building wheel for seqeval (setup.py): started
#   Building wheel for seqeval (setup.py): finished with status 'done'
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16170 sha256=03ac564d596384101374f1a1a2fe55d6b39efae56d23e6cf2ac64f0fc8be15f3
#   Stored in directory: /root/.cache/pip/wheels/05/96/ee/7cac4e74f3b19e3158dce26a20a1c86b3533c43ec72a549fd7
#   Building wheel for sklearn (setup.py): started
#   Building wheel for sklearn (setup.py): finished with status 'done'
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1316 sha256=93fb5108210f3837f66795d3d0d60cb01395600fee65ccba35dc296e9904b5e4
#   Stored in directory: /root/.cache/pip/wheels/46/ef/c3/157e41f5ee1372d1be90b09f74f82b10e391eaacca8f22d33e
# Successfully built prometheus-flask-exporter pyyaml databricks-cli alembic sacremoses future seqeval sklearn
# Installing collected packages: prometheus-client, itsdangerous, Werkzeug, click, MarkupSafe, Jinja2, Flask, prometheus-flask-exporter, querystring-parser, sqlparse, entrypoints, protobuf, smmap, gitdb, gitpython, pyyaml, chardet, idna, urllib3, requests, websocket-client, docker, azure-core, oauthlib, requests-oauthlib, isodate, msrest, pycparser, cffi, cryptography, azure-storage-blob, sqlalchemy, cloudpickle, tabulate, databricks-cli, gunicorn, Mako, python-editor, alembic, mlflow, pathspec, jmespath, zipp, importlib-metadata, jsonpickle, PyJWT, adal, msrestazure, azure-common, azure-mgmt-keyvault, azure-mgmt-authorization, contextlib2, azure-mgmt-storage, azure-graphrbac, ruamel.yaml.clib, ruamel.yaml, jeepney, SecretStorage, azure-mgmt-resource, azure-mgmt-containerregistry, backports.weakref, backports.tempfile, pyopenssl, pyasn1, ndg-httpsclient, azureml-core, azureml-mlflow, filelock, regex, joblib, tqdm, sacremoses, pyparsing, packaging, tokenizers, sentencepiece, transformers, future, dataclasses, typing-extensions, torch, tensorboardX, threadpoolctl, scikit-learn, seqeval, fastprogress, pillow, torchvision, pytorch-lamb, sklearn, python-box, murmurhash, plac, blis, srsly, wasabi, catalogue, cymem, preshed, thinc, spacy, more-itertools, cycler, kiwisolver, matplotlib, fast-bert, rsa, pyasn1-modules, cachetools, google-auth, tensorboard-plugin-wit, google-auth-oauthlib, markdown, absl-py, grpcio, tensorboard, pytorch-lightning
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.19.1
#     Uninstalling scikit-learn-0.19.1:
#       Successfully uninstalled scikit-learn-0.19.1
# Successfully installed Flask-1.1.2 Jinja2-2.11.2 Mako-1.1.3 MarkupSafe-1.1.1 PyJWT-1.7.1 SecretStorage-3.3.0 Werkzeug-1.0.1 absl-py-0.11.0 adal-1.2.5 alembic-1.4.1 azure-common-1.1.26 azure-core-1.9.0 azure-graphrbac-0.61.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-resource-10.3.0 azure-mgmt-storage-11.2.0 azure-storage-blob-12.6.0 azureml-core-1.18.0.post4 azureml-mlflow-1.18.0.post1 backports.tempfile-1.0 backports.weakref-1.0.post1 blis-0.7.3 cachetools-4.1.1 catalogue-1.0.0 cffi-1.14.4 chardet-3.0.4 click-7.1.2 cloudpickle-1.6.0 contextlib2-0.6.0.post1 cryptography-3.2.1 cycler-0.10.0 cymem-2.0.4 databricks-cli-0.14.1 dataclasses-0.6 docker-4.4.0 entrypoints-0.3 fast-bert-1.9.4 fastprogress-1.0.0 filelock-3.0.12 future-0.18.2 gitdb-4.0.5 gitpython-3.1.11 google-auth-1.23.0 google-auth-oauthlib-0.4.2 grpcio-1.33.2 gunicorn-20.0.4 idna-2.10 importlib-metadata-3.1.0 isodate-0.6.0 itsdangerous-1.1.0 jeepney-0.6.0 jmespath-0.10.0 joblib-0.17.0 jsonpickle-1.4.1 kiwisolver-1.3.1 markdown-3.3.3 matplotlib-3.3.3 mlflow-1.12.1 more-itertools-8.6.0 msrest-0.6.19 msrestazure-0.6.4 murmurhash-1.0.4 ndg-httpsclient-0.5.1 oauthlib-3.1.0 packaging-20.5 pathspec-0.8.1 pillow-8.0.1 plac-1.1.3 preshed-3.0.4 prometheus-client-0.9.0 prometheus-flask-exporter-0.18.1 protobuf-3.14.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 pycparser-2.20 pyopenssl-19.1.0 pyparsing-2.4.7 python-box-5.2.0 python-editor-1.0.4 pytorch-lamb-1.0.0 pytorch-lightning-0.8.1 pyyaml-5.3.1 querystring-parser-1.2.4 regex-2020.11.13 requests-2.25.0 requests-oauthlib-1.3.0 rsa-4.6 ruamel.yaml-0.16.12 ruamel.yaml.clib-0.2.2 sacremoses-0.0.43 scikit-learn-0.23.2 sentencepiece-0.1.91 seqeval-1.2.2 sklearn-0.0 smmap-3.0.4 spacy-2.3.4 sqlalchemy-1.3.20 sqlparse-0.4.1 srsly-1.0.4 tabulate-0.8.7 tensorboard-2.4.0 tensorboard-plugin-wit-1.7.0 tensorboardX-2.1 thinc-7.4.3 threadpoolctl-2.1.0 tokenizers-0.9.3 torch-1.7.0 torchvision-0.8.1 tqdm-4.54.0 transformers-3.5.1 typing-extensions-3.7.4.3 urllib3-1.26.2 wasabi-0.8.0 websocket-client-0.57.0 zipp-3.4.0
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_37005b8e9f6980b2f008f81139d8598f
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.12
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container 1ad7ef548e98
#  ---> 7ed7454fcbab
# Step 9/15 : ENV PATH /azureml-envs/azureml_37005b8e9f6980b2f008f81139d8598f/bin:$PATH
#  ---> Running in a20a74c902a1
# Removing intermediate container a20a74c902a1
#  ---> ea28612f882d
# Step 10/15 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_37005b8e9f6980b2f008f81139d8598f
#  ---> Running in 0e560c33e5a1
# Removing intermediate container 0e560c33e5a1
#  ---> b3b388394037
# Step 11/15 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_37005b8e9f6980b2f008f81139d8598f/lib:$LD_LIBRARY_PATH
#  ---> Running in 08a209f2fb1c
# Removing intermediate container 08a209f2fb1c
#  ---> fd46769c6582
# Step 12/15 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 2af29293aac9
# Step 13/15 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in bbccdcb023c6
# Removing intermediate container bbccdcb023c6
#  ---> 27e5f555164c
# Step 14/15 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 701bdff073d5
# Removing intermediate container 701bdff073d5
#  ---> 015d17fb2add
# Step 15/15 : CMD ["bash"]
#  ---> Running in 697df175fc7d
# Removing intermediate container 697df175fc7d
#  ---> 4fe0f61b20d1
# Successfully built 4fe0f61b20d1
# Successfully tagged 91000ffe28554e43abd795dd11872a0e.azurecr.io/azureml/azureml_2835514f63fd3fd36a5dbe19845d05e7:latest
# 2020/11/27 23:53:51 Successfully executed container: acb_step_0
# 2020/11/27 23:53:51 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/11/27 23:53:51 Pushing image: 91000ffe28554e43abd795dd11872a0e.azurecr.io/azureml/azureml_2835514f63fd3fd36a5dbe19845d05e7:latest, attempt 1
# The push refers to repository [91000ffe28554e43abd795dd11872a0e.azurecr.io/azureml/azureml_2835514f63fd3fd36a5dbe19845d05e7]
# 51c8874bbfd5: Preparing
# 91fca98bf3fb: Preparing
# 0066ba01713d: Preparing
# e13b2d20c860: Preparing
# d8188b78723b: Preparing
# d9440a9b1caa: Preparing
# 630330099f1e: Preparing
# 26346e33e93c: Preparing
# 65fd26c61dec: Preparing
# 8b72eff884fd: Preparing
# f06675a4a69e: Preparing
# 7117e7689e0f: Preparing
# d56ca49dab62: Preparing
# 09304b9c7c13: Preparing
# 9edaa71ce233: Preparing
# 62fdddf6a67c: Preparing
# eff16de3ff64: Preparing
# 61727f5e6796: Preparing
# d9440a9b1caa: Waiting
# 630330099f1e: Waiting
# 26346e33e93c: Waiting
# 65fd26c61dec: Waiting
# 8b72eff884fd: Waiting
# f06675a4a69e: Waiting
# 7117e7689e0f: Waiting
# d56ca49dab62: Waiting
# 09304b9c7c13: Waiting
# 9edaa71ce233: Waiting
# 62fdddf6a67c: Waiting
# eff16de3ff64: Waiting
# 61727f5e6796: Waiting
# 0066ba01713d: Pushed
# d8188b78723b: Pushed
# 51c8874bbfd5: Pushed
# e13b2d20c860: Pushed
# d9440a9b1caa: Pushed
# 630330099f1e: Pushed
# 26346e33e93c: Pushed
# 65fd26c61dec: Pushed
# d56ca49dab62: Pushed
# 7117e7689e0f: Pushed
# 8b72eff884fd: Pushed
# 9edaa71ce233: Pushed
# 62fdddf6a67c: Pushed
# eff16de3ff64: Pushed
# f06675a4a69e: Pushed
# 61727f5e6796: Pushed
# 09304b9c7c13: Pushed
#
# 91fca98bf3fb: Pushed
# latest: digest: sha256:b82f556bfc132c9f91ffd99735e386def18aeef0465877dc10a08220cd73f10f size: 4096
# 2020/11/27 23:58:20 Successfully pushed image: 91000ffe28554e43abd795dd11872a0e.azurecr.io/azureml/azureml_2835514f63fd3fd36a5dbe19845d05e7:latest
# 2020/11/27 23:58:20 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 296.248436)
# 2020/11/27 23:58:20 Populating digests for step ID: acb_step_0...
#
# Streaming azureml-logs/55_azureml-execution-tvmps_3dc022b3a445b80eccdcd4cb79a43b659dcd7b1ca94eb516599be6da3948df2a_p.txt
# ========================================================================================================================
#
# 2020-11-27T23:58:58Z Starting output-watcher...
# 2020-11-27T23:58:58Z IsDedicatedCompute == False, starting polling for Low-Pri Preemption
# 2020-11-27T23:59:00Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2020-11-27T23:59:00Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_2835514f63fd3fd36a5dbe19845d05e7
# 2c11b7cecaa5: Pulling fs layer
# 04637fa56252: Pulling fs layer
# d6e6af23a0f3: Pulling fs layer
# b4a424de92ad: Pulling fs layer
# 3e5d9ee64909: Pulling fs layer
# 3a846111ff22: Pulling fs layer
# 93a5020c6e19: Pulling fs layer
# 360b353e68fd: Pulling fs layer
# ea4e2e1810f8: Pulling fs layer
# def12cf7de15: Pulling fs layer
# 3ae6adfbdb11: Pulling fs layer
# 2a21fbf2232e: Pulling fs layer
# 8faedead895c: Pulling fs layer
# 901ee7d9039c: Pulling fs layer
# 4fdc72ea625c: Pulling fs layer
# 560765228463: Pulling fs layer
# 6725f255cdf5: Pulling fs layer
# ea4e2e1810f8: Waiting
# bf505e23fc9c: Pulling fs layer
# 3a846111ff22: Waiting
# 2a21fbf2232e: Waiting
# 3ae6adfbdb11: Waiting
# def12cf7de15: Waiting
# 360b353e68fd: Waiting
# 93a5020c6e19: Waiting
# 8faedead895c: Waiting
# 6725f255cdf5: Waiting
# 3e5d9ee64909: Waiting
# b4a424de92ad: Waiting
# 901ee7d9039c: Waiting
# 4fdc72ea625c: Waiting
# bf505e23fc9c: Waiting
# 560765228463: Waiting
# d6e6af23a0f3: Verifying Checksum
# d6e6af23a0f3: Download complete
# 04637fa56252: Verifying Checksum
# 04637fa56252: Download complete
# b4a424de92ad: Verifying Checksum
# b4a424de92ad: Download complete
# 2c11b7cecaa5: Verifying Checksum
# 2c11b7cecaa5: Download complete
# 3a846111ff22: Verifying Checksum
# 3a846111ff22: Download complete
# 3e5d9ee64909: Verifying Checksum
# 3e5d9ee64909: Download complete
# 93a5020c6e19: Download complete
# 360b353e68fd: Verifying Checksum
# 360b353e68fd: Download complete
# 3ae6adfbdb11: Verifying Checksum
# 3ae6adfbdb11: Download complete
# 2a21fbf2232e: Download complete
# 8faedead895c: Verifying Checksum
# 8faedead895c: Download complete
# 901ee7d9039c: Verifying Checksum
# 901ee7d9039c: Download complete
# 2c11b7cecaa5: Pull complete
# 4fdc72ea625c: Download complete
# 560765228463: Verifying Checksum
# 560765228463: Download complete
# 04637fa56252: Pull complete
# d6e6af23a0f3: Pull complete
# b4a424de92ad: Pull complete
# ea4e2e1810f8: Verifying Checksum
# ea4e2e1810f8: Download complete
# bf505e23fc9c: Verifying Checksum
# bf505e23fc9c: Download complete
# 3e5d9ee64909: Pull complete
# 3a846111ff22: Pull complete
# def12cf7de15: Verifying Checksum
# def12cf7de15: Download complete
# 93a5020c6e19: Pull complete
# 360b353e68fd: Pull complete
# 6725f255cdf5: Verifying Checksum
# 6725f255cdf5: Download complete
# ea4e2e1810f8: Pull complete
# def12cf7de15: Pull complete
# 3ae6adfbdb11: Pull complete
# 2a21fbf2232e: Pull complete
# 8faedead895c: Pull complete
# 901ee7d9039c: Pull complete
# 4fdc72ea625c: Pull complete
# 560765228463: Pull complete
# Submitted Run failed with exception ActivityFailedException:
# 	Message: Activity Failed:
# {
#     "error": {
#         "code": "UserError",
#         "message": "AzureMLCompute job failed.\nJobFailed: Submitted script failed with a non-zero exit code; see the driver log file for details.",
#         "details": []
#     },
#     "correlation": {
#         "operation": null,
#         "request": "4592292b744aa156"
#     },
#     "environment": "southcentralus",
#     "location": "southcentralus",
#     "time": "2020-11-28T00:00:18.372736Z",
#     "componentName": "execution-worker"
# }
# 	InnerException None
# 	ErrorResponse
# {
#     "error": {
#         "message": "Activity Failed:\n{\n    \"error\": {\n        \"code\": \"UserError\",\n        \"message\": \"AzureMLCompute job failed.\\nJobFailed: Submitted script failed with a non-zero exit code; see the driver log file for details.\",\n        \"details\": []\n    },\n    \"correlation\": {\n        \"operation\": null,\n        \"request\": \"4592292b744aa156\"\n    },\n    \"environment\": \"southcentralus\",\n    \"location\": \"southcentralus\",\n    \"time\": \"2020-11-28T00:00:18.372736Z\",\n    \"componentName\": \"execution-worker\"\n}"
#     }
# }
#
# Streaming azureml-logs/75_job_post-tvmps_3dc022b3a445b80eccdcd4cb79a43b659dcd7b1ca94eb516599be6da3948df2a_p.txt
# ===============================================================================================================
#
# [2020-11-27T23:59:58.992294] Entering job release
# [2020-11-27T23:59:59.756193] Starting job release
# [2020-11-27T23:59:59.761482] Logging experiment finalizing status in history service.
# [2020-11-27T23:59:59.761621] job release stage : upload_datastore starting...Starting the daemon thread to refresh tokens in background for process with pid = 167
# [2020-11-27T23:59:59.761902] job release stage : start importing azureml.history._tracking in run_history_release.
# [2020-11-27T23:59:59.762135] job release stage : copy_batchai_cached_logs starting...
#
# [2020-11-27T23:59:59.763831] job release stage : copy_batchai_cached_logs completed...[2020-11-27T23:59:59.763866] job release stage : execute_job_release starting...
#
# [2020-11-27T23:59:59.764321] Entering context manager injector.
# [2020-11-27T23:59:59.765258] job release stage : upload_datastore completed...
# [2020-11-28T00:00:00.005530] job release stage : send_run_telemetry starting...
# [2020-11-28T00:00:00.131195] job release stage : execute_job_release completed...
# [2020-11-28T00:00:01.494010] job release stage : send_run_telemetry completed...
# [2020-11-28T00:00:01.494177] Job release is complete
#
# Execution Summary
# =================
# RunId: fast-bert-ner_1606520924_3ca09039
# Web View: https://ml.azure.com/experiments/fast-bert-ner/runs/fast-bert-ner_1606520924_3ca09039?wsid=/subscriptions/d35ad7f3-a6be-400c-b1db-8b70322a01a0/resourcegroups/scan-datasources-rg/workspaces/zd-ner
# ---------------------------------------------------------------------------
# ExecutionException                        Traceback (most recent call last)
# <ipython-input-20-82837e2a610e> in <module>
# ----> 1 remote_mlflow_run = mlflow.projects.run(uri=".",
#       2                                     parameters={"json_config": "training_config.json"},
#       3                                     backend="azureml",
#       4                                     backend_config=backend_config,
#       5                                     synchronous=True)
#
# ~/Onedrive/multifit_ner/env/lib/python3.8/site-packages/mlflow/projects/__init__.py in run(uri, entry_point, version, parameters, docker_args, experiment_name, experiment_id, backend, backend_config, use_conda, storage_dir, synchronous, run_id)
#     308     )
#     309     if synchronous:
# --> 310         _wait_for(submitted_run_obj)
#     311     return submitted_run_obj
#     312
#
# ~/Onedrive/multifit_ner/env/lib/python3.8/site-packages/mlflow/projects/__init__.py in _wait_for(submitted_run_obj)
#     325         else:
#     326             _maybe_set_run_terminated(active_run, "FAILED")
# --> 327             raise ExecutionException("Run (ID '%s') failed" % run_id)
#     328     except KeyboardInterrupt:
#     329         _logger.error("=== Run (ID '%s') interrupted, cancelling run ===", run_id)
#
# ExecutionException: Run (ID 'fast-bert-ner_1606520924_3ca09039') failed

# %%
remote_mlflow_run
